# %% [markdown]
# <div style="border:solid blue 2px; padding: 20px">
#
# **Привет, Полина!**
#
# Меня зовут Юлия Никишина, я ревьюер, буду проверять твой проект.
#
# Если не против, я буду обращаться к тебе на "ты". Если это неприемлемо, обязательно напиши мне в комментариях, и мы перейдем на "Вы".
#
# Далее в файле ты увидишь мои комментарии в цветных ячейках с пометкой "Комментарий ревьюера". Цвет ячеек зависит от того, какие действия от тебя требуются, ниже указано подробнее.
#
# **Важно:** Пожалуйста, не удаляй и не изменяй мои комментарии. При повторной проверке я буду ориентироваться на них.
#
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <b>✅ Комментарий ревьюера (хорошо)</b>
#
# Такими комментариями я буду отмечать хорошо проделаную работу.
# </div>
#
# <div class="alert alert-warning"; style="border-left: 7px solid gold">
# <b>⚠️ Комментарий ревьюера (обрати внимание)</b>
#
# Части проекта, помеченные такими комментариями, можно не исправлять, но стоит обратить на них внимание. В таких комментариях я постараюсь предложить альтернативный вариант решения или дам рекомендации на будущее.
# </div>
#
# <div class="alert alert-danger"; style="border-left: 7px solid red">
# <b>⛔️ Комментарий ревьюера (нужно исправить)</b>
#
# Если ты видишь такой комментарий, значит я указываю тебе на недочёт, его нужно исправить. Без такого исправления я не смогу принять твою работу.
# </div>
#
# Ты можешь под моими комментариями оставлять свои, описывать в них сделанные исправления или задавать вопросы, выделяя их другим цветом.
#
# <div class="alert alert-info"; style="border-left: 7px solid blue">
# <b>Комментарий студента</b>

# %% [markdown]
# <div style="border:solid blue 2px; padding: 20px">
#
# **Заключительный комментарий, ревью 3**
#
# Полина, привет.
#
# Спасибо за быструю доработку проекта. Ты исправила все критичные замечания.
#
# Твой проект принят, поздравляю. Оставила тебе подробный комментарий, который, надеюсь, поможет лучше понять причины неокупаемости.
#
#
# Желаю тебе успехов в дальнейшем обучении.

# %% [markdown]
# <div style="border:solid blue 2px; padding: 20px">
#
# **Заключительный комментарий, ревью 2**
#
# Полина, привет.
#
# Спасибо, что добавила исследование в разрезе устройств по регионам. Однако, не вижу, чтобы ты описала графики и пересмотрела выводы. Кажется, некоторые выводы не соответствуют тому, что мы видим на графикам. Пожалуйста, посмотри мои вопросы и постарайся разобраться.
#
# Буду ждать обновленный проект.

# %% [markdown]
# <div style="border:solid blue 2px; padding: 20px">
#
# **Заключительный комментарий**
#
# Полина, спасибо за проект. У тебя получилась хорошая работа.
#
# - Ты следовала предложенной структуре
# - Описывала свои наблюдения
# - Вывела отличные сводные таблицы с нужной информацией
#
# ---
#
# Есть несколько моментов, которые необходимо улучшить, чтобы проект был принят, они описаны в ячейках с красным фоном по ходу тетрадки. Пожалуйста, доработай их и присылай проект на повторную проверку.
#
# Также по желанию можешь доработать желтые комментарии.
#
# Желаю тебе успехов и буду ждать твой проект.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента VERS#1<a class="tocSkip"></h2>
# Не поняла задание "Постройте визуализацию динамики изменения расходов во времени (по неделям и месяцам) по каждому источнику. Постарайтесь отразить это на одном графике." Если отражать их на одном графике, то я придумала только через дни объединить, но тогда получается непонятно какая неделя и месяц без подписей. А в неделях много точек и подписи к каждой выглядят гроздко и не аккуратно. Если имелось в виду через plt.subplot, то это же не один график. Надеюсь ты поможешь мне с этим разобраться.
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента VERS#2<a class="tocSkip"></h2>
# Не поняла зачем искать общее среднее CAC по каналам без учета дат, если аггрегирование по датам, а потом нахождение среднего показывает динамику изменения CAC. Сразу можно уведеть странный рост, а не просто значение. У меня сложилось впечатление, что с группировкой по датам выглядит как-то нагляднее. P.S. надеюсь сейчас с выводами все норм, спасибо.
#
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <b>✅ Комментарий ревьюера, ревью 2</b>
#
# Динамику CAC мы видим на графикам в части анализа окупаемости. А это предварительный этап, где мы изучаем общие показатели, пока без углубления в детали.
# </div>

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <b>✅ Комментарий ревьюера, ревью 1</b>
#
# Конечно, помогу разобраться ) Да, имелись в виду как раз отдельные графики через `subplot()`. Согласна, задание звучит не очень понятно 🤷🏻‍♀️
#
# Посмотрим дальше, как у тебя это реализовано и требуется ли доработка.

# %% [markdown]
# # Сборный проект Анализ бизнес-показателей

# %% [markdown]
# ## Описание проекта

# %% [markdown]
# Нам предстоит провести исследоавние и ответить на вопрос "почему компания терипт убытки". Объект исследования - данные о рекламной кампании, а именно логи о посещениях, данные о покупках пользователей и рекламные расходы. Приступим к анализу!

# %% [markdown]
# ## Цели и задачи проекта

# %% [markdown]
# - откуда приходят пользователи и какими устройствами они пользуются
#
# - сколько стоит привлечение пользователей из различных рекламных каналов
#
# - сколько денег приносит каждый клиент
#
# - когда расходы на привлечение клиента окупаются
#
# - какие факторы мешают привлечению клиентов

# %% [markdown]
# ## Описание данных

# %% [markdown]
# В вашем распоряжении три датасета. Файл visits_info_short.csv хранит лог сервера с информацией о посещениях сайта, orders_info_short.csv — информацию о заказах, а costs_info_short.csv — информацию о расходах на рекламу.
#
# Структура visits_info_short.csv:
#
# * User Id — уникальный идентификатор пользователя,
#
# * Region — страна пользователя,
#
# * Device — тип устройства пользователя,
#
# * Channel — идентификатор источника перехода,
#
# * Session Start — дата и время начала сессии,
#
# * Session End — дата и время окончания сессии.
#
# Структура orders_info_short.csv:
#
# * User Id — уникальный идентификатор пользователя,
#
# * Event Dt — дата и время покупки,
#
# * Revenue — сумма заказа.
#
# Структура costs_info_short.csv:
#
# * dt — дата проведения рекламной кампании,
#
# * Channel — идентификатор рекламного источника,
#
# * costs — расходы на эту кампанию.

# %% [markdown]
# ## План работы

# %% [markdown]
# * Загрузка данных
# * Предобработка данных
# * Создание функции для расчёта и анализа LTV, ROI, удержания и конверсии
# * Исследовательский анализ данных
# * Маркетинг
# * Оценка окупаемости рекламы
# * Выводы

# %% [markdown]
# <div class="alert alert-warning"; style="border-left: 7px solid gold">
# <b>⚠️ Комментарий ревьюера, ревью 2</b>
#
# Не стоит копировать в качестве введения текст ТЗ. Лучше кратко выделить основное. Писать введение, как и весь текст в проекте стоит от первого лица во множественном числе "Нам предстоит провести исследования... Мы изучили..." и т.д.

# %% [markdown]
# ## 1. Загрузка данных

# %% [markdown]
# <div class="alert alert-warning"; style="border-left: 7px solid gold">
# <b>⚠️ Комментарий ревьюера, ревью 1</b>
#
# Обратила внимание, что у тебя нумерация ячеек начинается не с единицы. Перед отправкой стоит перезапускать тетрадку и выполнять весь код (в меню `Kernel -> Restart and Run All`), чтобы убедиться, что у ревьюера все отработает без сбоев.
#
# Если ты просто выполнишь код заново без перезапуска ядра, то нет уверенности, что у ревьюера все отработает ОК, так как некоторые переменные могли у тебя сохраниться в памяти с прошлого запуска, а у ревьюера это не сработает.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy import stats as st
import warnings
warnings.simplefilter("ignore")
pd.set_option('display.max_columns', None)
from datetime import datetime, timedelta

# %matplotlib inline

# %%
try:
  visits = pd.read_csv('visits_info_short.csv')
  orders = pd.read_csv('orders_info_short.csv')
  costs = pd.read_csv('costs_info_short.csv')
except:
  visits = pd.read_csv('https://code.s3.yandex.net/datasets/visits_info_short.csv')
  orders = pd.read_csv('https://code.s3.yandex.net/datasets/orders_info_short.csv')
  costs = pd.read_csv('https://code.s3.yandex.net/datasets/costs_info_short.csv')

# %% [markdown]
# Посмотрим сырые данные и посмотрим нужна ли предобработка

# %%
visits.head()
# Out:
#         User Id         Region   Device  Channel        Session Start  \
# 0  981449118918  United States   iPhone  organic  2019-05-01 02:36:01
# 1  278965908054  United States   iPhone  organic  2019-05-01 04:46:31
# 2  590706206550  United States      Mac  organic  2019-05-01 14:09:25
# 3  326433527971  United States  Android   TipTop  2019-05-01 00:29:59
# 4  349773784594  United States      Mac  organic  2019-05-01 03:33:35
#
#            Session End
# 0  2019-05-01 02:45:01
# 1  2019-05-01 04:47:35
# 2  2019-05-01 15:32:08
# 3  2019-05-01 00:54:25
# 4  2019-05-01 03:57:40

# %%
orders.head()
# Out:
#         User Id             Event Dt  Revenue
# 0  188246423999  2019-05-01 23:09:52     4.99
# 1  174361394180  2019-05-01 12:24:04     4.99
# 2  529610067795  2019-05-01 11:34:04     4.99
# 3  319939546352  2019-05-01 15:34:40     4.99
# 4  366000285810  2019-05-01 13:59:51     4.99

# %%
costs.head()
# Out:
#            dt   Channel  costs
# 0  2019-05-01  FaceBoom  113.3
# 1  2019-05-02  FaceBoom   78.1
# 2  2019-05-03  FaceBoom   85.8
# 3  2019-05-04  FaceBoom  136.4
# 4  2019-05-05  FaceBoom  122.1

# %%
visits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   User Id        309901 non-null  int64
#  1   Region         309901 non-null  object
#  2   Device         309901 non-null  object
#  3   Channel        309901 non-null  object
#  4   Session Start  309901 non-null  object
#  5   Session End    309901 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 14.2+ MB

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   User Id   40212 non-null  int64
#  1   Event Dt  40212 non-null  object
#  2   Revenue   40212 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 942.6+ KB

# %%
costs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   dt       1800 non-null   object
#  1   Channel  1800 non-null   object
#  2   costs    1800 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 42.3+ KB

# %% [markdown]
# Пропусков в данных нет, но названия столбцов неудобны для работы с ними, данные о дате и времени сессий хранятся в неудобном типе. Исправвим это в следующих шагах.

# %% [markdown]
# ## 2. Предобработка данных

# %% [markdown]
# Для начала, приведем названия столбцов к нижнему регистру

# %%
visits.columns = map(str.lower, visits.columns)
orders.columns = map(str.lower, orders.columns)
costs.columns = map(str.lower, costs.columns)

# %% [markdown]
# DataFrame costs с названиями столбцов, которые удобны в работе. Для остальных данных воспользуемся методом rename

# %%
visits.rename(columns={'user id': 'user_id', 'session start': 'session_start', 'session end': 'session_end'}, inplace=True)
orders.rename(columns={'user id': 'user_id', 'event dt': 'event_dt'}, inplace=True)

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <b>✅ Комментарий ревьюера, ревью 1</b>
#
# Молодец, что стандартизируешь названия столбцов.

# %%
print(visits.columns)
print(orders.columns)
print(costs.columns)
# Out:
# Index(['user_id', 'region', 'device', 'channel', 'session_start',
#        'session_end'],
#       dtype='object')
# Index(['user_id', 'event_dt', 'revenue'], dtype='object')
# Index(['dt', 'channel', 'costs'], dtype='object')

# %% [markdown]
# С названиями все хорошо, остались типы данных. Изменим типы данных в столбцах, содержащих дату, с object на datetime

# %%
visits['session_start'] = pd.to_datetime(visits['session_start'])
visits['session_end'] = pd.to_datetime(visits['session_end'])
orders['event_dt'] = pd.to_datetime(orders['event_dt'])
costs['dt'] = pd.to_datetime(costs['dt']).dt.date

# %% [markdown]
# Теперь нас все устраивает для дальнейшей работы с данными

# %% [markdown]
# Проверим есть ли явные дубликаты в данных

# %%
visits.duplicated().sum()
# Out:
# 0

# %%
orders.duplicated().sum()
# Out:
# 0

# %%
costs.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Дубликатов нет. На этом предобработку данных можно завершать

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <b>✅ Комментарий ревьюера, ревью 1</b>
#
#
# Ты тщательно изучила данные и сделала все неоходимые преобразования и проверки.

# %% [markdown]
# ## 3. Создание функции для расчёта и анализа LTV, ROI, удержания и конверсии

# %% [markdown]
# Функция get_profiles формирует профили CAC. На вход подаются
#
# sessions - информация о сессиях пользователей (user_id, session_start, channel, device, region)
#
# orders - информация о заказах (user_id)
#
# ad_costs - информация о стоимости рекламных расходов (costs)
#
# В скобках отражены обязательные столбцы, с которыми работает функция.

# %%
def get_profiles(sessions, orders, ad_costs):

    # сортируем сессии по ID пользователя и дате привлечения
    # группируем по ID и находим параметры первых посещений
    profiles = (
        sessions.sort_values(by=['user_id', 'session_start'])
        .groupby('user_id')
        .agg(
            {
                'session_start': 'first',
                'channel': 'first',
                'device': 'first',
                'region': 'first',
            }
        )
         # время первого посещения назовём first_ts
        .rename(columns={'session_start': 'first_ts'})
        .reset_index()  # возвращаем user_id из индекса
    )

    # для когортного анализа определяем дату первого посещения
    # и первый день месяца, в который это посещение произошло
    profiles['dt'] = profiles['first_ts'].dt.date
    profiles['month'] = profiles['first_ts'].astype('datetime64[M]')

    # добавляем признак платящих пользователей
    profiles['payer'] = profiles['user_id'].isin(orders['user_id'].unique())

    # считаем количество уникальных пользователей
    # с одинаковыми источником и датой привлечения
    new_users = (
        profiles.groupby(['dt', 'channel'])
        .agg({'user_id': 'nunique'})
         # столбец с числом пользователей назовём unique_users
        .rename(columns={'user_id': 'unique_users'})
        .reset_index()  # возвращаем dt и channel из индексов
    )

    # объединяем траты на рекламу и число привлечённых пользователей
    # по дате и каналу привлечения
    ad_costs = ad_costs.merge(new_users, on=['dt', 'channel'], how='left')

    # делим рекламные расходы на число привлечённых пользователей
    # результаты сохраним в столбец acquisition_cost (CAC)
    ad_costs['acquisition_cost'] = ad_costs['costs'] / ad_costs['unique_users']

    # добавим стоимость привлечения в профили
    profiles = profiles.merge(
        ad_costs[['dt', 'channel', 'acquisition_cost']],
        on=['dt', 'channel'],
        how='left',
    )

    # органические пользователи не связаны с данными о рекламе,
    # поэтому в столбце acquisition_cost у них значения NaN
    # заменим их на ноль, ведь стоимость привлечения равна нулю
    profiles['acquisition_cost'] = profiles['acquisition_cost'].fillna(
        0
    )
    
    return profiles  # возвращаем профили с CAC

# %% [markdown]
# Функция get_retention() возвращает 2 таблицы удержания и сырые данные. На вход подаются
#
# profiles - информация о CAC (first_ts)
#
# sessions - информация о сессиях пользователей (user_id, session_start)
#
# observation_date - максимальная дата анализа
#
# horizon_days - горизонт анализа
#
# dimensions - столбцы, по которым искать когорты, по умолчанию пустой список
#
# ignore_horizon - по уолчанию False, определяет будет ли учитываться горизонт анализа
#
# В скобках отражены обязательные столбцы, с которыми работает функция.

# %%
def get_retention(profiles, sessions, observation_date, horizon_days, dimensions = [], ignore_horizon = False):
    
    # решаем какие столбцы оставим для группировки удержания, столбец признака платящего пользователя остается всегда
    dimensions = ['payer'] + dimensions
    
    # оттсекаем всех пользователей, которые не могли "дожить" до нужного горизонта 
    # (присоединились позже чем observation_date - horizon)
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(days = horizon_days - 1)
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # формируем массив сырых данных
    result_raw = result_raw.merge(sessions[['user_id', 'session_start']], on = 'user_id', how = 'left')
    result_raw['lifetime'] = (result_raw['session_start'] - result_raw['first_ts']).dt.days
    
    # функция группировки по нужному набору измерений
    def group_by_dimensions(df, dims, horizon_days):     
        result = df.pivot_table(index = dims, columns = 'lifetime', values = 'user_id', aggfunc = 'nunique')     # строим "треугольную таблицу" 
        cohort_sizes = df.groupby(dims).agg({'user_id': 'nunique'}).rename(columns = {'user_id': 'cohort_size'}) # определяем размеры когорт
        result = cohort_sizes.merge(result, on = dims, how = 'left').fillna(0)                                   # присоединяем размеры когорт к треугольной таблице
        result = result.div(result['cohort_size'], axis = 0)                                                     # делим каждый из столбцов на размер когорты - расчитываем % удержания (retention rate)
        result = result[['cohort_size'] + list(range(horizon_days))]                                             # оставляем только наблюдения до нужного горизонта и столбец размеров когорт
        result['cohort_size'] = cohort_sizes                                                                     # пересприсваиваем столбец размеров когорт, ведь во время деления он превратился в 1
        return result
    
    # расчитываем удержание 
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)
    
    # рассчитываем удержание по всем параметрам + дата
    result_in_time = group_by_dimensions(result_raw, dimensions + ['dt'], horizon_days)
    
    # возвращаем и таблицы удержания и сырые данные (чтобы в случае чего можно было в них покопаться при отладке)
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# Функция get_conversion() возвращает 2 таблицы конверсии и сырые данные. На вход подаются
#
# profiles - информация о CAC (first_ts)
#
# purchases - информация о покупках (user_id, event_dt)
#
# observation_date - максимальная дата анализа
#
# horizon_days - горизонт анализа
#
# dimensions - столбцы, по которым искать когорты, по умолчанию пустой список
#
# ignore_horizon - по уолчанию False, определяет будет ли учитываться горизонт анализа
#
# В скобках отражены обязательные столбцы, с которыми работает функция.

# %%
def get_conversion(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # определяем дату и время первой покупки для каждого пользователя
    first_purchases = (
        purchases.sort_values(by=['user_id', 'event_dt'])
        .groupby('user_id')
        .agg({'event_dt': 'first'})
        .reset_index()
    )

    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        first_purchases[['user_id', 'event_dt']], on='user_id', how='left'
    )

    # рассчитываем лайфтайм для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days

    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users'
        dimensions = dimensions + ['cohort']

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        # строим «треугольную» таблицу конверсии
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        # считаем сумму с накоплением для каждой строки
        result = result.fillna(0).cumsum(axis = 1)
        # вычисляем размеры когорт
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        # добавляем размеры когорт в таблицу конверсии
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # делим каждую «ячейку» в строке на размер когорты
        # и получаем conversion rate
        result = result.div(result['cohort_size'], axis=0)
        # исключаем все лайфтаймы, превышающие горизонт анализа
        result = result[['cohort_size'] + list(range(horizon_days))]
        # восстанавливаем размеры когорт
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу конверсии
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # для таблицы динамики конверсии убираем 'cohort' из dimensions
    if 'cohort' in dimensions: 
        dimensions = []

    # получаем таблицу динамики конверсии
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# Функция get_ltv() возвращает 2 таблицы LTV, 2 таблицы ROI и сырые данные. На вход подаются
#
# profiles - информация о CAC (first_ts)
#
# purchases - информация о покупках (user_id, event_dt, revenue)
#
# observation_date - максимальная дата анализа
#
# horizon_days - горизонт анализа
#
# dimensions - столбцы, по которым искать когорты, по умолчанию пустой список
#
# ignore_horizon - по уолчанию False, определяет будет ли учитываться горизонт анализа
#
# В скобках отражены обязательные столбцы, с которыми работает функция.

# %%
def get_ltv(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')
    result_raw = result_raw.merge(
        purchases[['user_id', 'event_dt', 'revenue']], on='user_id', how='left'
    )
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days

    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users'
        dimensions = dimensions + ['cohort']

    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='revenue', aggfunc='sum'
        )
        result = result.fillna(0).cumsum(axis=1)
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        cac = df[['user_id', 'acquisition_cost'] + dims].drop_duplicates()
        cac = (
            cac.groupby(dims)
            .agg({'acquisition_cost': 'mean'})
            .rename(columns={'acquisition_cost': 'cac'})
        )
        roi = result.div(cac['cac'], axis=0)
        roi = roi[~roi['cohort_size'].isin([np.inf])]
        roi['cohort_size'] = cohort_sizes
        roi['cac'] = cac['cac']
        roi = roi[['cohort_size', 'cac'] + list(range(horizon_days))]
        return result, roi

    result_grouped, roi_grouped = group_by_dimensions(
        result_raw, dimensions, horizon_days
    )
    if 'cohort' in dimensions:
        dimensions = []
    result_in_time, roi_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    return (
        result_raw,  # сырые данные
        result_grouped,  # таблица LTV
        result_in_time,  # таблица динамики LTV
        roi_grouped,  # таблица ROI
        roi_in_time,  # таблица динамики ROI
    )

# %% [markdown]
# Функция filter_data сглаживает DataFrame с заданным окном. На вход подаются
#
# df - DataFrame для дальнейшего сглаживания
#
# window - окно сглаживания

# %%
def filter_data(df, window):
    # для каждого столбца применяем скользящее среднее
    for column in df.columns.values:
        df[column] = df[column].rolling(window).mean() 
    return df

# %% [markdown]
# Функция plot_retention() визуализирует графики удержания. На вход подаются
#
# retention - DataFrame из функции get_retention (cohort_size, 0, payer)
#
# retention_history - DataFrame из функции get_retention (dt, cohort_size)
#
# horizon - горизонт анализа
#
# window - окно сглаживания, по умолчанию 7
#
# В скобках отражены обязательные столбцы, с которыми работает функция.

# %%
def plot_retention(retention, retention_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 10))

    # исключаем размеры когорт и удержание первого дня
    retention = retention.drop(columns=['cohort_size', 0])
    # в таблице динамики оставляем только нужный лайфтайм
    retention_history = retention_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # если в индексах таблицы удержания только payer,
    # добавляем второй признак — cohort
    if retention.index.nlevels == 1:
        retention['cohort'] = 'All users'
        retention = retention.reset_index().set_index(['cohort', 'payer'])

    # в таблице графиков — два столбца и две строки, четыре ячейки
    # в первой строим кривые удержания платящих пользователей
    ax1 = plt.subplot(2, 2, 1)
    retention.query('payer == True').droplevel('payer').T.plot(
        grid=True, ax=ax1
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание платящих пользователей')

    # во второй ячейке строим кривые удержания неплатящих
    # вертикальная ось — от графика из первой ячейки
    ax2 = plt.subplot(2, 2, 2, sharey=ax1)
    retention.query('payer == False').droplevel('payer').T.plot(
        grid=True, ax=ax2
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание неплатящих пользователей')

    # в третьей ячейке — динамика удержания платящих
    ax3 = plt.subplot(2, 2, 3)
    # получаем названия столбцов для сводной таблицы
    columns = [
        name
        for name in retention_history.index.names
        if name not in ['dt', 'payer']
    ]
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == True').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания платящих пользователей на {}-й день'.format(
            horizon
        )
    )

    # в четвёртой ячейке — динамика удержания неплатящих
    ax4 = plt.subplot(2, 2, 4, sharey=ax3)
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == False').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax4)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания неплатящих пользователей на {}-й день'.format(
            horizon
        )
    )
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# Функция plot_conversion визуализирует графики конверсии. На вход подаются
#
# conversion - DataFrame из функции get_conversion (cohort_size, 0, payer)
#
# conversion_history - DataFrame из функции get_conversion (dt, cohort_size)
#
# horizon - горизонт анализа
#
# window - окно сглаживания, по умолчанию 7
#
# В скобках отражены обязательные столбцы, с которыми работает функция.

# %%
def plot_conversion(conversion, conversion_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 5))

    # исключаем размеры когорт
    conversion = conversion.drop(columns=['cohort_size'])
    # в таблице динамики оставляем только нужный лайфтайм
    conversion_history = conversion_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # первый график — кривые конверсии
    ax1 = plt.subplot(1, 2, 1)
    conversion.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Конверсия пользователей')

    # второй график — динамика конверсии
    ax2 = plt.subplot(1, 2, 2, sharey=ax1)
    columns = [
        # столбцами сводной таблицы станут все столбцы индекса, кроме даты
        name for name in conversion_history.index.names if name not in ['dt']
    ]
    filtered_data = conversion_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика конверсии пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# Функция plot_ltv_roi визуализирует графики LTV и ROI. На вход подаются
#
# ltv - DataFrame из функции get_ltv (cohort_size, 0, payer)
#
# ltv_history - DataFrame из функции get_ltv (dt, cohort_size)
#
# roi - DataFrame из функции get_ltv (cohort_size, 0, payer)
#
# roi_history - DataFrame из функции get_ltv (dt, cohort_size, cac)
#
# horizon - горизонт анализа
#
# window - окно сглаживания, по умолчанию 7
#
# В скобках отражены обязательные столбцы, с которыми работает функция.

# %%
def plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon, window=7):

    # задаём сетку отрисовки графиков
    plt.figure(figsize=(20, 10))

    # из таблицы ltv исключаем размеры когорт
    ltv = ltv.drop(columns=['cohort_size'])
    # в таблице динамики ltv оставляем только нужный лайфтайм
    ltv_history = ltv_history.drop(columns=['cohort_size'])[[horizon - 1]]

    # стоимость привлечения запишем в отдельный фрейм
    cac_history = roi_history[['cac']]

    # из таблицы roi исключаем размеры когорт и cac
    roi = roi.drop(columns=['cohort_size', 'cac'])
    # в таблице динамики roi оставляем только нужный лайфтайм
    roi_history = roi_history.drop(columns=['cohort_size', 'cac'])[
        [horizon - 1]
    ]

    # первый график — кривые ltv
    ax1 = plt.subplot(2, 3, 1)
    ltv.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('LTV')

    # второй график — динамика ltv
    ax2 = plt.subplot(2, 3, 2, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in ltv_history.index.names if name not in ['dt']]
    filtered_data = ltv_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика LTV пользователей на {}-й день'.format(horizon))

    # третий график — динамика cac
    ax3 = plt.subplot(2, 3, 3, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in cac_history.index.names if name not in ['dt']]
    filtered_data = cac_history.pivot_table(
        index='dt', columns=columns, values='cac', aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика стоимости привлечения пользователей')

    # четвёртый график — кривые roi
    ax4 = plt.subplot(2, 3, 4)
    roi.T.plot(grid=True, ax=ax4)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('ROI')

    # пятый график — динамика roi
    ax5 = plt.subplot(2, 3, 5, sharey=ax4)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in roi_history.index.names if name not in ['dt']]
    filtered_data = roi_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax5)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.xlabel('Дата привлечения')
    plt.title('Динамика ROI пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <b>✅ Комментарий ревьюера, ревью 1</b>
#
# Необходимые функции заданы, можем приступать к анализу.

# %% [markdown]
# ## 3. Исследовательский анализ данных

# %% [markdown]
# ### Составим профили пользователей. Определим минимальную и максимальную даты привлечения пользователей

# %%
# Создадим профили пользователей
profiles = get_profiles(visits, orders, costs)
# Минимальная дата привлечения пользователей
min_analysis_date = profiles['first_ts'].min()
# Макимальная дата привлечения пользователей
observation_date = profiles['first_ts'].max()

# %%
profiles['dt'] = profiles['first_ts'].dt.date
profiles['dt'] = pd.to_datetime(profiles['dt'], format="%Y-%m-%d")
profiles['month'] = profiles['first_ts'].astype('datetime64[M]')

# %%
profiles
# Out:
#              user_id            first_ts       channel  device         region  \
# 0             599326 2019-05-07 20:58:57      FaceBoom     Mac  United States
# 1            4919697 2019-07-09 12:46:07      FaceBoom  iPhone  United States
# 2            6085896 2019-10-01 09:58:33       organic  iPhone         France
# 3           22593348 2019-08-22 21:35:48    AdNonSense      PC        Germany
# 4           31989216 2019-10-02 00:07:44       YRabbit  iPhone  United States
# ...              ...                 ...           ...     ...            ...
# 150003  999956196527 2019-09-28 08:33:02        TipTop  iPhone  United States
# 150004  999975439887 2019-10-21 00:35:17       organic      PC             UK
# 150005  999976332130 2019-07-23 02:57:06        TipTop  iPhone  United States
# 150006  999979924135 2019-09-28 21:28:09  MediaTornado      PC  United States
# 150007  999999563947 2019-10-18 19:57:25       organic  iPhone  United States
#
# ...

# %% [markdown]
# <div class="alert alert-warning"; style="border-left: 7px solid gold">
# <b>⚠️ Комментарий ревьюера, ревью 1</b>
#
# Чтобы датафрейм отображался в привычном табличном виде, используй функцию `display()` вместо `print()`.
#
# Если команда на вывод датафрейма расположена в последней строке ячейки, то вообще нет необходимости использовать какой-либо из указанных выше методов.

# %%
print(f'Минимальная дата привлечения пользователей {min_analysis_date} \nМакимальная дата привлечения пользователей {observation_date}')
# Out:
# Минимальная дата привлечения пользователей 2019-05-01 00:00:41
# Макимальная дата привлечения пользователей 2019-10-27 23:59:04

# %% [markdown]
# Видим, что функция get_profiles сработала успешно. Также определили минимальную и максимальную дату привлечения пользователей. Анализировать будем с 1 мая 2019 по 27 октября 2019

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <b>✅ Комментарий ревьюера, ревью 1</b>
#
# Да, профили созданы верно.
#
# Стоило отметить, что даты соответствуют датам в ТЗ.

# %% [markdown]
# ### Выясним, из каких стран пользователи приходят в приложение и на какую страну приходится больше всего платящих пользователей. Построим таблицу, отражающую количество пользователей и долю платящих из каждой страны.

# %%
region_by_users = pd.DataFrame()
region_by_users['users'] = profiles.groupby('region').agg({'user_id': 'nunique'})
region_by_users['paying_users'] = profiles.query('payer == True').groupby('region').agg({'user_id': 'nunique'})
region_by_users['percent_payer'] = round(region_by_users['paying_users'] / region_by_users['users'] * 100, 2)
region_by_users.reset_index(inplace=True)

# %%
region_by_users.sort_values(by='percent_payer', ascending=True)
# Out:
#           region   users  paying_users  percent_payer
# 0         France   17450           663           3.80
# 2             UK   17575           700           3.98
# 1        Germany   14981           616           4.11
# 3  United States  100002          6902           6.90

# %% [markdown]
# Рассматриваем мы только пользователей из Франции, Великобритании, Германии и США. Последняя страна является лидером среди платящих пользователей

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <b>✅ Комментарий ревьюера, ревью 1</b>
#
# Да, верно, видим, что большая часть наших платящих пользователей из США, да и просто большая часть пользователей тоже оттуда.
#
# ---
#
# Отмечу также, что ты отлично оформила таблицы: столбцы имеют понятные названия, доля переведена в проценты, значения процентов округлены.

# %% [markdown]
# ### Узнаем, какими устройствами пользуются клиенты и какие устройства предпочитают платящие пользователи. Построим таблицу, отражающую количество пользователей и долю платящих для каждого устройства.

# %%
device_user = pd.DataFrame()
device_user['users'] = profiles.groupby('device').agg({'user_id': 'nunique'})
device_user['paying_users'] = profiles.query('payer == True').groupby('device').agg({'user_id': 'nunique'})
device_user['percent_payer'] = round(device_user['paying_users'] / device_user['users'] * 100, 2)
device_user.reset_index(inplace=True)

# %%
device_user.sort_values(by='percent_payer')
# Out:
#     device  users  paying_users  percent_payer
# 2       PC  30455          1537           5.05
# 0  Android  35032          2050           5.85
# 3   iPhone  54479          3382           6.21
# 1      Mac  30042          1912           6.36

# %% [markdown]
# Среди пользователей есть всего 4 платформы: PC, Android, iPhone, Mac. Среди пользователей платищих больше всего на платформе Mac

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <b>✅ Комментарий ревьюера, ревью 1</b>
#
# Верно. Большая часть наших платящих пользователей предпочитает устройства Apple. Возможно, это связано с тем, что наш основной рынок США, где данные устройства очень популярны.

# %% [markdown]
# ### Изучим рекламные источники привлечения и определим каналы, из которых пришло больше всего платящих пользователей. Построим таблицу, отражающую количество пользователей и долю платящих для каждого канала привлечения.

# %%
channel_users = pd.DataFrame()
channel_users['users'] = profiles.groupby('channel').agg({'user_id': 'nunique'})
channel_users['paying_users'] = profiles.query('payer == True').groupby('channel').agg({'user_id': 'nunique'})
channel_users['percent_payer'] = round(channel_users['paying_users'] / channel_users['users'] * 100, 2)
channel_users.reset_index(inplace=True)

# %%
channel_users.sort_values(by='percent_payer')
# Out:
#                channel  users  paying_users  percent_payer
# 10             organic  56439          1160           2.06
# 4   OppleCreativeMedia   8605           233           2.71
# 2              LeapBob   8553           262           3.06
# 3         MediaTornado   4364           156           3.57
# 8              YRabbit   4312           165           3.83
# 7       WahooNetBanner   8553           453           5.30
# 5       RocketSuperAds   4448           352           7.91
# 6               TipTop  19561          1878           9.60
# 9       lambdaMediaAds   2149           225          10.47
# 0           AdNonSense   3880           440          11.34
# 1             FaceBoom  29144          3557          12.20

# %% [markdown]
# Каналов привлечения много. Канал organic явлеяется каналом с наименьшим процентом платящих пользователей. У канала FaceBoom самый большой процент платящих пользователей

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <b>✅ Комментарий ревьюера, ревью 1</b>
#
# Обрати внимание, что organic - это не канал. Под этим навзванием объединены пользователи, которые пришли к нам напрямую, не через рекламные каналы.
#
# Больше всего платящих пользователей пришло из каналов FaceBoom, TipTop и органически. А вот доля платящих выше у FaceBoom, AdNonSense, lambdaMediaAds.

# %% [markdown]
# Общий вывод: на данном этапе были определены страны, устройства и каналы с самым большим процентом платящих пользователей. В будущем с этим можно поработать и увеличить лояльность этих клиентов (например, эксклюзивными предложениями для стран, а также определенными фишками фронтэнда для устройств) и привлечь новых.

# %% [markdown]
# ## 4. Маркетинг

# %% [markdown]
# ### Посчитаем общую сумму расходов на маркетинг

# %%
sum_costs = costs['costs'].sum()
print(round(sum_costs, 1))
# Out:
# 105497.3

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <b>✅ Комментарий ревьюера, ревью 1</b>
#
# Да, верно.

# %% [markdown]
# ### Выясним, как траты распределены по рекламным источникам, то есть сколько денег потратили на каждый источник.

# %%
total_costs = pd.DataFrame()
total_costs['costs_by_channel'] = costs.groupby('channel').agg({'costs': 'sum'})
total_costs.reset_index(inplace=True)

# %%
total_costs.sort_values(by='costs_by_channel')
# Out:
#               channel  costs_by_channel
# 8             YRabbit            944.22
# 3        MediaTornado            954.48
# 9      lambdaMediaAds           1557.60
# 2             LeapBob           1797.60
# 5      RocketSuperAds           1833.00
# 4  OppleCreativeMedia           2151.25
# 0          AdNonSense           3911.25
# 7      WahooNetBanner           5151.00
# 1            FaceBoom          32445.60
# 6              TipTop          54751.30

# %%
total_costs['costs_by_channel'].sum()
# Out:
# 105497.30000000002

# %%
total_costs['percentage'] = total_costs['costs_by_channel'] / total_costs['costs_by_channel'].sum() * 100
display(total_costs)
# Out:
#               channel  costs_by_channel  percentage
# 0          AdNonSense           3911.25    3.707441
# 1            FaceBoom          32445.60   30.754910
# 2             LeapBob           1797.60    1.703930
# 3        MediaTornado            954.48    0.904744
# 4  OppleCreativeMedia           2151.25    2.039152
# 5      RocketSuperAds           1833.00    1.737485
# 6              TipTop          54751.30   51.898295
# 7      WahooNetBanner           5151.00    4.882589
# 8             YRabbit            944.22    0.895018
# 9      lambdaMediaAds           1557.60    1.476436

# %% [markdown]
# Общая сумма на маркетинг сходится с суммой расходов на каждый канал привлечения пользователей. Всего каналов 10, organic не входит в это число, ведь расходов у него нет. Более 80% расходов приходится на каналы FaceBoom и TipTop

# %% [markdown]
# <div class="alert alert-warning"; style="border-left: 7px solid gold">
# <b>⚠️ Комментарий ревьюера, ревью 1</b>
#
# Здесь стоит сделать акцент на распределении расходов. Хорошо было бы показать не только суммы, но и долю каждого канала в расходах. Как мы видим, у нас более 80% расходов приходится на 2 канала.

# %% [markdown]
# ### Построим визуализацию динамики изменения расходов во времени (по неделям и месяцам) по каждому источнику. Постарайтесь отразить это на одном графике

# %% [markdown]
# Добавим столбцы week и month, чтобы дальше сгруппировать по этому столбцу и визуализировать данные по неделям и месяцам. Возьмем одну ось с расходами, чтобы показать наглядно различия в порядке суммы расходов

# %%
costs['dt'] = pd.to_datetime(costs['dt'])
costs['week'] = costs['dt'].dt.isocalendar().week
costs['month'] = costs['dt'].dt.month

# %%
costs.week
# Out:
# 0       18
# 1       18
# 2       18
# 3       18
# 4       18
#         ..
# 1795    43
# 1796    43
# 1797    43
# 1798    43
# 1799    43
# Name: week, Length: 1800, dtype: UInt32

# %%
weekly_costs = costs.groupby('week').agg({'costs': 'sum'}).reset_index()
monthly_costs = costs.groupby('month').agg({'costs': 'sum'}).reset_index()

# %%
plt.figure(figsize = (20, 6))
ax1 = plt.subplot(1,2,1)
weekly_costs.plot(x='week',
                 y='costs',
                 grid=True,
                 ax=ax1,
                 xlabel='Неделя',
                 ylabel='Расходы на рекламу, $',
                 title='Динамика изменения расходов во времени (по неделям)')
plt.legend(['Расходы'])
plt.scatter(weekly_costs.week, weekly_costs.costs)

ax2 = plt.subplot(1,2,2, sharey=ax1)
monthly_costs.plot(x='month',
                   y='costs',
                   grid=True,
                   ax=ax2,
                   xlabel='Месяц',
                   ylabel='Расходы на рекламу, $',
                   title='Динамика изменения расходов во времени (по месяцам)')
plt.legend(['Расходы'])
plt.scatter(monthly_costs.month, monthly_costs.costs);

# %% [markdown]
# Ниже представлен ОДИН график с динамикой изменений расходов.

# %% [markdown]
# <div class="alert alert-danger"; style="border-left: 7px solid red">
# <b>⛔️ Комментарий ревьюера, ревью 1</b>
#
# <a class="tocSkip"></a><s>Да, график все-таки придется доработать. Он прекрасно у тебя сделан в виде подграфиков. Есть заголовки, оси подписаны 👌🏼 Но нужно показать разбивку по каналам. Пожалуйста, добавь.
#
# ---
#
# И не забудь прокомментировать свои наблюдения.

# %%
weekly_costs_channel = costs.groupby(['channel','week']).agg({'costs': 'sum'}).reset_index()
monthly_costs_channel = costs.groupby(['channel', 'month']).agg({'costs': 'sum'}).reset_index()

# %%
plt.figure(figsize = (20, 6))
list_channels = list(weekly_costs_channel['channel'].unique())
ax1 = plt.subplot(1,2,1)
for i, chan in enumerate(list_channels):
  weekly_costs_channel.query('channel == @chan').plot(x='week',
                 y='costs',
                 grid=True,
                 ax=ax1,
                 xlabel='Неделя',
                 ylabel='Расходы на рекламу, $',
                 title=f'Динамика изменения расходов во времени (по неделям) для каналов')
plt.legend(list_channels)

ax2 = plt.subplot(1,2,2, sharey=ax1)
for i, chan in enumerate(list_channels):
  monthly_costs_channel.query('channel == @chan').plot(x='month',
                   y='costs',
                   grid=True,
                   ax=ax2,
                   xlabel='Месяц',
                   ylabel='Расходы на рекламу, $',
                   title='Динамика изменения расходов во времени (по месяцам)')
plt.legend(list_channels);

# %%
# plt.figure(figsize = (10,6))
# plt.plot(weekly_costs.week * 7, weekly_costs.costs, label = "Расходы по неделям")
# plt.scatter(weekly_costs.week * 7, weekly_costs.costs)
# plt.plot(monthly_costs.month * (365 / 12), monthly_costs.costs, label = "Расходы по месяцам")
# plt.scatter(monthly_costs.month * (365 / 12), monthly_costs.costs)
# plt.title('Динамика изменения расходов во времени (по неделям и месяцам)')
# plt.xlabel('Дни')
# plt.ylabel('Расходы, $')
# plt.grid()
# plt.legend()
# for i, week_num in enumerate(weekly_costs['week']):
#   plt.annotate(week_num, (weekly_costs.week[i] * 7, weekly_costs.costs[i]))
# for i, month_num in enumerate(monthly_costs['month']):
#   plt.annotate(month_num, (monthly_costs.month[i] * 365/12, monthly_costs.costs[i]))

# %% [markdown]
# В среднем в неделю тратили 4000\\$ на рекламу, а в месяц 17500\\$. Из графиков видно, что каналы TipTop и FaceBoom имеют расходы в несколько раз превышающие расходы остальных каналов привлечения, дальше разберемся окупаются ли такие расходы.

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <b>✅ Комментарий ревьюера, ревью 2</b>
#
# Да, верно.

# %% [markdown]
# ### Узнаем, сколько в среднем стоило привлечение одного пользователя (CAC) из каждого источника. Используем профили пользователей.

# %% [markdown]
# Построим сводную таблицу для того, что узнать сколько стоило привлечь одно пользователя из разных рекламных источников

# %%
profiles.pivot_table(
    index='dt', columns='channel', values='acquisition_cost', aggfunc='mean'
).plot(grid=True, figsize=(10, 5))
plt.ylabel('CAC, $')
plt.xlabel('Дата привлечения')
plt.title('Динамика САС по каналам привлечения')
plt.show()

# %% [markdown]
# Получившейся график сложно интерпретировать, поэтому воспользуемся функцией сглаживания данных. Установим окно сглаживания равным 7 дням.

# %%
pivot_profiles = profiles.pivot_table(
    index='dt', columns='channel', values='acquisition_cost', aggfunc='mean'
)
filtered_profiles = filter_data(pivot_profiles, 7)
filtered_profiles.plot(grid=True, figsize=(15, 10))
plt.ylabel('CAC, $')
plt.xlabel('Дата привлечения')
plt.title('Динамика САС по каналам привлечения')
plt.show()

# %%
pivot_profiles.mean()
# Out:
# channel
# AdNonSense            1.010271
# FaceBoom              1.113068
# LeapBob               0.209514
# MediaTornado          0.218465
# OppleCreativeMedia    0.249307
# RocketSuperAds        0.406413
# TipTop                2.669928
# WahooNetBanner        0.599747
# YRabbit               0.209047
# lambdaMediaAds        0.722201
# organic               0.000000
# dtype: float64

# %%
profiles_group_channel = profiles.groupby('channel').agg({'acquisition_cost': 'mean'}).reset_index().sort_values(by='acquisition_cost', ascending=False)
profiles_group_channel
list_channels = list(profiles_group_channel['channel'])

# %%
profiles_group_channel.sort_values(by='acquisition_cost', ascending=False).plot(kind='bar',
                                                                                 figsize=(15,10))
plt.xticks(range(len(list_channels)), list_channels);

# %% [markdown]
# <div class="alert alert-danger"; style="border-left: 7px solid red">
# <b>⛔️ Комментарий ревьюера, ревью 1</b>
#
# Нужно доработать расчет. Тебе не нужно агрегировать данные по датам, а потом находить среднее среди всех дат. Просто рассчитай сразу среднее за весь период для каждого канала. И отсортируй таблицу по убыванию, чтобы сразу было видно, кто лидирует по стоимости.
#
# <div class="alert alert-warning"; style="border-left: 7px solid gold">
# <b>⚠️ Комментарий ревьюера, ревью 2</b>
#
# OK. Нужна была еще, конечно, таблица. Но согласна, мой комментарий не очень явно на это указывал.

# %% [markdown]
# Стало лучше, стоимость привлечения "органических" пользователей равна 0 - все в порядке. Стоимость привлечения пользователей из каналов YRabbit, OppleCreativeNedia, LeapBob и MediaTornado условно стабильна и равна ~25 центов. RocketSuperAds на момент начала анализа была ~55 центов, а к концу анализа упала до 25 центов. lambdaMediaAds стабильна в диапазоне от 60 до 75 центов. WahooNetBanner - ~55 центов. FaceBoom - ~1.2 доллара за пользователя. AdNonSense - от 1.2 до 0.9. А вот стоимость привлечения пользователей через TipTop выросла  от 1 доллара до 3.6 Особое внимание уделить этому каналу привлечения, окупается ли эта стоимость привлечения?

# %% [markdown]
# ## Оценка окупаемости рекламы

# %% [markdown]
# Исходные данные:
#
# - момент анализа 1 ноября 2019
# - горизовнт анализа 14 дней
# - включать "органических" пользователей на усмотрение

# %% [markdown]
# ### Проанализируем окупаемость рекламы c помощью графиков LTV и ROI, а также графики динамики LTV, CAC и ROI

# %%
#min_date = profiles['first_ts'].min()
observation_date = pd.to_datetime('2019-11-1')
#days_num = (observation_date - min_date).days
analysis_horizon = 14

#daily_costs = []

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <b>✅ Комментарий ревьюера, ревью 1</b>
#
# Временные рамки анализа (дата анализа и период окупаемости) заданы верно. Стоило прокомментировать, что это за переменные и откуда мы взяли информацию для них.

# %% [markdown]
# <div class="alert alert-warning"; style="border-left: 7px solid gold">
# <b>⚠️ Комментарий ревьюера, ревью 1</b>
#
# Насколько понимаю, ты не используешь `min_date`, days_num` и `daily_costs`. Стоило их убрать в закомментированный код, чтобы поддерживать используемый код чистым и понятным.

# %%
# for index, values in costs.iterrows():

#     channel_name = values['channel'] # определите канал привлечения
#     channel_costs = values['costs'] # и общие рекламные траты на него
#     avg_channel_costs = channel_costs / days_num # рассчитайте средние траты за день

#     # заполняем таблицу рекламных трат
#     for i in range(days_num):
#         current_day = min_date + timedelta(days=i) # рассчитайте текущую дату
#         # добавляем строку в таблицу трат
#         daily_costs += [[current_day, channel_name, avg_channel_costs]]

# # превращаем таблицу рекламных трат в датафрейм
# daily_costs = pd.DataFrame(daily_costs, columns=['dt', 'channel', 'costs'])
# # преобразуем данные о времени
# daily_costs['dt'] = daily_costs['dt'].dt.date

# %% [markdown]
# Не будем учитывать органических пользователей, чтобы они не исказили данные о прибыли

# %%
profiles = profiles.query('channel != "organic"')

# %% [markdown]
# <div class="alert alert-danger"; style="border-left: 7px solid red">
# <b>⛔️ Комментарий ревьюера, ревью 1</b>
#
# <a class="tocSkip"></a><s>Однако, нужно было исключить органиков - за их привлечение мы ничего не платим, поэтому не стоит учитывать прибыль, которую они приносят.
#
# Пересмотри свои выводы после исключения - в некоторых случаях картина поменяется. Я проверю детально оставшуюся часть после доработки. Сейчас укажу только на критические моменты, если такие будут.

# %%
ltv_raw, ltv, ltv_history, roi, roi_history = get_ltv(profiles, orders, observation_date, analysis_horizon)

plot_ltv_roi(ltv, ltv_history, roi, roi_history,analysis_horizon, window=14)

# %% [markdown]
# Инвестиции в рекламу не окупаются. Необходимо посмотреть на различные факторы окупаемости рекламы (каналы привлечения, устройства, страны) и определить где необходимо провести изменения, чтобы выйти в плюс

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <b>✅ Комментарий ревьюера, ревью 2</b>
#
# OK, давай посмотрим.

# %% [markdown]
# ### Проверим конверсию пользователей и динамику её изменения. То же самое сделаем с удержанием пользователей. Построим и изучим графики конверсии и удержания.

# %%
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, analysis_horizon, dimensions=['channel']
)

plot_conversion(conversion_grouped, conversion_history, analysis_horizon, window=14)

# %% [markdown]
# Самая высокая конверсия у пользователей, привлеченных каналом FaceBoom. В конверсии также наблюдается сезонность.

# %% [markdown]
# Посмотрим на графики удержания пользователей

# %%
retention_raw, retention_grouped, retention_history = get_retention(profiles,
visits, observation_date, analysis_horizon, dimensions=['channel'])

plot_retention(retention_grouped, retention_history, analysis_horizon)

# %% [markdown]
# Удержание платящих пользователей из FaceBoom и AdNonSense намного ниже, чем у остальных каналов.

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <b>✅ Комментарий ревьюера, ревью 2</b>
#
# Да, очень плохое удержание платящих, на уровне неплатящих, у FaceBoom и AdNonSense. Хотя конверсия у обоих каналов самая высокая.

# %% [markdown]
# ### Проанализируем окупаемость рекламы с разбивкой по устройствам. Построим графики LTV и ROI, а также графики динамики LTV, CAC и ROI

# %%
ltv_raw, ltv, ltv_history, roi, roi_history = get_ltv(profiles, orders, observation_date, analysis_horizon, dimensions=['device'])

plot_ltv_roi(ltv, ltv_history, roi, roi_history,analysis_horizon, window=14)

# %%
retention_raw, retention_grouped, retention_history = get_retention(profiles,
visits, observation_date, analysis_horizon, dimensions=['device'])

plot_retention(retention_grouped, retention_history, analysis_horizon)

# %%
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, analysis_horizon, dimensions=['device']
)

plot_conversion(conversion_grouped, conversion_history, analysis_horizon, window=14)

# %% [markdown]
# Окупаются лучше всего пользователи с PC, не окупаюся пользователи с iPhone и Mac, к тому же у них самая высокая стоимость привлечения. Динамика удержания неплатящих пользователей на уровне 0 для всех устройств. Самая высокая конерсия у пользователей Mac, а самая низкая у PC

# %% [markdown]
# <div class="alert alert-warning"; style="border-left: 7px solid gold">
# <b>⚠️ Комментарий ревьюера, ревью 2</b>
#
# Пользователи всех устройств, кроме ПК, перестали окупаться начале лета, что совпало по времени с увеличением стоимости их привлечения. Но к настоящему моменту уже не окупаются все устройства.
#
# Также можем заметить, что хотя значения показателей и отличаются по устройствам, динамика для всех устройств примерно одинаковая. То есть проблема скорее всего не связана с определенным типом устройства.
#
# Стоило еще посмотреть конверсию по устройствам.

# %% [markdown]
# ### Проанализируем окупаемость рекламы с разбивкой по странам. Построим графики LTV и ROI, а также графики динамики LTV, CAC и ROI.

# %%
ltv_raw, ltv, ltv_history, roi, roi_history = get_ltv(profiles, orders, observation_date, analysis_horizon, dimensions=['region'])

plot_ltv_roi(ltv, ltv_history, roi, roi_history,analysis_horizon, window=14)

# %%
retention_raw, retention_grouped, retention_history = get_retention(profiles,
visits, observation_date, analysis_horizon, dimensions=['region'])

plot_retention(retention_grouped, retention_history, analysis_horizon)

# %% [markdown]
# Из всех представленных стран, не окупается только США, стоимость привлечения пользователей растет очень быстро. Можно предположить, что канал привлечения TipTop привлекает пользователей из США, характер графиков похож. Удержание пользователей США, также самое низкое

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <b>✅ Комментарий ревьюера, ревью 2</b>
#
# Да, США - единственный регион, в котором реклама не окупается, несмотря на более высокий LTV.
#
# Действительно, из этого графика можем сделать вывод, что это связано как минимум с высокой стоимостью привлечения (похоже, и правда, это сильно связано с TipTop), потому что в динамике ROI заметно, что снижение повторяет динамику роста CAC.

# %% [markdown]
# ### Проанализируем окупаемость рекламы с разбивкой по рекламным каналам. Построим графики LTV и ROI, а также графики динамики LTV, CAC и ROI

# %%
ltv_raw, ltv, ltv_history, roi, roi_history = get_ltv(profiles, orders, observation_date, analysis_horizon, dimensions=['channel'])

plot_ltv_roi(ltv, ltv_history, roi, roi_history,analysis_horizon, window=14)

# %% [markdown]
# Из всех каналов TipTop имеет уникальный вид, высокий рост цены привлечения пользователей, также самый низкий ROI, несомтря на хороший LTV. Возможно стоит уменьшить бюджет или вовсе отказаться от сотрудничества. У YRabbit большой ROI, несмотря на низкий LTV, один из самых прибыльных каналов.

# %% [markdown]
# Рассмотрим отдельно устройства в США и Европе

# %%
profiles.region.unique()
# Out:
# array(['United States', 'Germany', 'France', 'UK'], dtype=object)

# %%
usa = profiles.query('region == "United States"')
europe = profiles.query('region != "United States"')

# %%
ltv_raw, ltv, ltv_history, roi, roi_history = get_ltv(usa, orders, observation_date, analysis_horizon, dimensions=['device'])

plot_ltv_roi(ltv, ltv_history, roi, roi_history,analysis_horizon, window=14)

# %% [markdown]
# Судя по графику ни одно устройство не окупается и динамика ROI падает. Стоит подумать что можно изменить, чтобы ROI устройств вышло в плюс.

# %% [markdown]
# <div class="alert alert-warning"; style="border-left: 7px solid gold">
# <b>⚠️ Комментарий ревьюера, ревью 3</b>
#
# Этот график говорит нам, что в США ни одно устройство не окупается. То есть дело не в устройствах, а в регионе.

# %%
retention_raw, retention_grouped, retention_history = get_retention(usa,
visits, observation_date, analysis_horizon, dimensions=['device'])

plot_retention(retention_grouped, retention_history, analysis_horizon)

# %% [markdown]
# Можно подумать над бонусами при повторной покупке, чтобы повысить удержание пользователей.

# %% [markdown]
# <div class="alert alert-warning"; style="border-left: 7px solid gold">
# <b>⚠️ Комментарий ревьюера, ревью 3</b>
#
# В удержании разницы между устройствами тоже нет.

# %%
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    usa, orders, observation_date, analysis_horizon, dimensions=['device']
)

plot_conversion(conversion_grouped, conversion_history, analysis_horizon, window=14)

# %% [markdown]
# Конверсия выглядит неплохо, Android лидирует.

# %% [markdown]
# Отдельно посмотрим на Европу

# %%
ltv_raw, ltv, ltv_history, roi, roi_history = get_ltv(europe, orders, observation_date, analysis_horizon, dimensions=['device'])

plot_ltv_roi(ltv, ltv_history, roi, roi_history,analysis_horizon, window=14)

# %% [markdown]
# Здесь окупаются все устройства примерно на 5 день, пользователи IOS немного нестабильны

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <b>✅ Комментарий ревьюера, ревью 3</b>
#
# Абсолютно верно - здесь все устройства окупаются, и Apple, и Android и PC.

# %%
retention_raw, retention_grouped, retention_history = get_retention(europe,
visits, observation_date, analysis_horizon, dimensions=['device'])

plot_retention(retention_grouped, retention_history, analysis_horizon)

# %% [markdown]
# Удержание платящих пользователей в Европе лучше, чем в США.

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <b>✅ Комментарий ревьюера, ревью 1</b>
#
# Да, верно. Но внутри региона особых отличий в устройствах нет.

# %% [markdown]
# Посмотрим на каналы привлечения по странам

# %%
ltv_raw, ltv, ltv_history, roi, roi_history = get_ltv(usa, orders, observation_date, analysis_horizon, dimensions=['channel'])

plot_ltv_roi(ltv, ltv_history, roi, roi_history,analysis_horizon, window=14)

# %% [markdown]
# Стоимость привлечения клиентов в США стабильна только для одного канала (FaceBoom), для канала TipTop она увеличилась больше, чем в 3 раза, у остальных каналов CAC уменьшилось. Не окупаются инвестиции в первые два канала (FaceBoom, TipTop) и ROI в динамике у них очень низкие.

# %%
ltv_raw, ltv, ltv_history, roi, roi_history = get_ltv(europe, orders, observation_date, analysis_horizon, dimensions=['channel'])

plot_ltv_roi(ltv, ltv_history, roi, roi_history,analysis_horizon, window=14)

# %% [markdown]
# В Европе окупается вся реклама, кроме AdNonSense, стоимость привлечения пользователей стабильна. У lambdaMediaAds LTV выше, чем у остальных каналов в Европе, этот канал - перспективная точка роста. Динамика ROI у большинства каналов выше уровня окупаемости, AdNonSense балансирует на грани окупаемости.

# %%
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    europe, orders, observation_date, analysis_horizon, dimensions=['device']
)

plot_conversion(conversion_grouped, conversion_history, analysis_horizon, window=14)

# %% [markdown]
# Здесь конверсия меньше, чем в США. Возможно стоит проанализировать товар, выявить предпочтения пользователей и расширить ассортимент.

# %% [markdown]
# Практически все рекламные компании окупаются, кроме TipTop, FaceBoom, AdNonSense

# %% [markdown]
# Самый высокий LTV у пользователей из lambdaMediaAds и TipTop.
#
# Хоть пользователи из TipTop приносят много прибыли как видно из LTV, но затраты на их привлечение не окупает прибыль от них. Так же пользователи из каналов FaceBoom и AdNonSense не окупаются. Стоить подумать как изменить ситуацию: отказаться от рекламы через эти источники или пересмотреть бюджет для этих каналов

# %% [markdown]
# **Общий вывод:** В целом реклама не окупается, складывается это из-за неокупаемости каналов привлечения (TipTop, FaceBoom, AdNonSense), страны (США). Проблемы окупаемости могут быть в большой стоимости привлечения пользователей и их малом количестве, неправильном распределении бюджета на каналы привлечения.

# %% [markdown]
# В США не окупается реклама, стоит изменить каналы привлечения пользователей и платный контент

# %% [markdown]
# <div class="alert alert-warning"; style="border-left: 7px solid gold">
# <b>⚠️ Комментарий ревьюера, ревью 3</b>
#
# Ты опять пишешь про устройства, пользователи которых лучше окупаются и удерживаются. На самом деле разница не в устройствах, а в регионах.
#
# Основная причина неокупаемостии - неэффективная рекламная кампания в США. Там в качестве основных каналов рекламы используются неэффективные TipTop и FaceBoom (в Европе данных каналы не используются). TipTop не окупается в связи с высокой стоимостью рекламы, а FaceBoom - в связи с низким удержанием пользователей.
#
# Пользователи устройств Apple имеют более низкие показатели окупаемости и удержания как раз потому, что эти устройства в основном используются в США. Если посмотреть отдельно Европу, там пользователи этих устройств не выглядят хуже, чем пользователи других устройств.
#
# Но при этом в США есть и каналы с хорошими показателями окупаемости, которые окупаются буквально на 3-5 день. И эти каналы нам бы и стоило рассмотреть в качестве альтернативных.

# %% [markdown]
# <div class="alert alert-danger"; style="border-left: 7px solid red">
# <b>⛔️ Комментарий ревьюера, ревью 2</b>
#
# <a class="tocSkip"></a><s>Спасибо, что добавила графики по США и Европе выше. Сделай описание под каждым графиком, пожалуйста. Посмотри внимательно окупаемость устройств в Европе и в США. Есть ли разница? Почему ты рекомендуешь смотреть на пользователей с устройствами PC и далее в выводах пишешь о проблемах с устройствами iOS? Пересмотри, пожалуйста, общие выводы.
#
# ---
#
# Также не понимаю последний абзац в выводе выше. Где ты видишь такую разницу в конверсии?

# %% [markdown]
# <div class="alert alert-danger"; style="border-left: 7px solid red">
# <b>⛔️ Комментарий ревьюера, ревью 1</b>
#
#
#
# <a class="tocSkip"></a><s>Пожалуйста, посмотри, как окупаются разные устройства отдельно в США и отдельно в Европе (графики LTV, ROI, CAC). Это поможет понять, если ли разница между устройствами.
#
# ---
#
# И сформулируй, пожалуйста, видимые причины неокупаемости TipTop, FaceBoom и AdNonSense.

# %% [markdown]
# ## Выводы

# %% [markdown]
# Причины неэффективности привлечения пользователей:
# 3 канала привлечения пользователей не окупились (TipTop(США), FaceBoom(США), AdNonSense(Европа)). Удержание платящих пользователей США оказалось самым низким, ROI в динамике показал, что с каждым месяцем пользователи США окупались все хуже, а в июне перестали окупаться вовсе, а стоимлсть привлечения жителей США только увеличивалась. В Еропе только один рекламный канал не окупается, но конверсия пользователей меньше, чем в США.
#  * Возможные причины проблемы пользователей из США:
# * 1. В июне что-то произошло, что пользователи изменили свое поведение
# * 2. Никакие устройствва не окупаются в США, возможно стоит найти уменьшения расходов (если это возможно)
# * 3. Рекламная кампания TipTop оказалась неэффективной, но бюджет продолжали выделять и увеличивать
#
# Необоснованный рост стоимости привлечения клиентов через TipTop.
#
# Также можно провести обновление платного контента для канала FaceBoom, конверсия была очень высокой, но удержание самое низкое, вероятно, причина в плохом качестве платного контента.

# %% [markdown]
# <div class="alert alert-danger"; style="border-left: 7px solid red">
# <b>⛔️ Комментарий ревьюера, ревью 1</b>
#
#
# <a class="tocSkip"></a><s>Как ты поняла, что основные пользователи TipTop, FaceBoom и AdNonSense из США? Вообще, это хорошая идея посмотреть, как распределены рекламные каналы по странам.
#
# <div class="alert alert-danger"; style="border-left: 7px solid red">
# <b>⛔️ Комментарий ревьюера, ревью 2</b>
#
# В этом блоке тоже требуется корректировка выводов в части устройств.

# %% [markdown]
# Рекомендации для отдела маркетинга:
#  - Поиск новых каналов привлечения пользователей из Великобритании и Германии, у них самый большой ROI
#  - Привлечение большего количества пользователей PC и Android, у них лучшее удержание среди платящих пользователей. В Еропе самая большая конверсия у пользвотелей PC, а в США - Android.
#  - Наибольший ROI среди каналов привлечения: Yrabbit, MediaTornado, lambdaMediaAds. Можно увеличить бюджет
#  - Изменение рекламной кампании в США.

# %% [markdown]
# <div class="alert alert-warning"; style="border-left: 7px solid gold">
# <b>⚠️ Комментарий ревьюера, ревью 1</b>
#
# Посмотри, пожалуйста, возможно, потребуется пересмотреть выводы после дополнения анализа (в части устройств).
